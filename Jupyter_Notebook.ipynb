# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Title

# %% [markdown]
# #### Introduction

# %% [markdown]
# List of data science languages:
# 1. Python
# 2. R
# 3. SQL
# 4. Scale
# 5. Java
# 6. C++
# 7. Julia

# %% [markdown]
# List of data science libraries:
# 1. pandas
# 2. numpy
# 3. scipy
# 4. dplyr
# 5. stringr
# 6. ggplot
# 7. caret

# %% [markdown]
# List of data science tools:
# 1. Execution environment
# 2. Data asset management
# 3. Data management
# 4. Data integraty and transformation
# 5. Data visualisation
# 6. Model building
# 7. Model deployment
# 8. Model moitoring and assessment

# %%
1+1 #introducing arithmetic expression examples
# Out:
# 2

# %%
(2*5)+10 #a code cell to multiply and add numbers
# Out:
# 20

# %%
#a code cell to convert minutes to hours
totalminutes= 100
hours = totalminutes//60
minutes = totalminutes %60
print(f"{totalminutes} minutes is equal to {hours} hours and {minutes} minutes.")
# Out:
# 100 minutes is equal to 1 hours and 40 minutes.

# %% [markdown]
# Ojectives:
# 1. To learn python
# 2. Practice coding

# %% [markdown]
# Author

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
